# %% [markdown]
# <h1><strong><u>Digit Model Deployment</u></strong></h1>

# %%
from sklearn2pmml import sklearn2pmml
from sklearn2pmml.pipeline import PMMLPipeline

# %%
# %%capture
# %run FinalDigitClassifier.ipynb

# %%
final_classifier = final_digit_classifier()
print(final_classifier)
# Out:
# Pipeline(steps=[('clf',
#                  Pipeline(steps=[('clf',
#                                   KNeighborsClassifier(n_neighbors=3))]))])

# %%
deployment_pl = PMMLPipeline(
    [
        ("clf", final_classifier)
    ]
)
deployment_pl.fit(X, y)
sklearn2pmml(deployment_pl, "digit_classifier_v1.pmml")
# Out:
# Exception ignored in: <function ResourceTracker.__del__ at 0x10751dbc0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x1037d9bc0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x108741bc0>
# ...
